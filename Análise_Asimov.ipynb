# %% [markdown]
# <a href="https://colab.research.google.com/github/JNarimatsu/Asimov_Analise_Dados/blob/main/An%C3%A1lise_Asimov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''ano = 2023
caminho_dados = f"/content/drive/MyDrive/Asimov/Análise de dados /{ano}_Viagem.csv"
caminho_saida_tabela = f"/content/drive/MyDrive/Asimov/Análise de dados /Output/{ano}_Viagem_consolidado.xlsx"
caminho_saida_grafico = f"/content/drive/MyDrive/Asimov/Análise de dados /Output/{ano}_Viagem_consolidado.png" '''
# Out:
# 'ano = 2023\ncaminho_dados = f"/content/drive/MyDrive/Asimov/Análise de dados /{ano}_Viagem.csv"\ncaminho_saida_tabela = f"/content/drive/MyDrive/Asimov/Análise de dados /Output/{ano}_Viagem_consolidado.xlsx"\ncaminho_saida_grafico = f"/content/drive/MyDrive/Asimov/Análise de dados /Output/{ano}_Viagem_consolidado.png" '

# %%
#Vinculando o caminho do conjunto de dados a uma variável
caminho_dados = "/content/drive/MyDrive/Asimov/Análise de dados /2023_Viagem.csv"

# %%
import pandas as pd

# %%
#utilizamos df como padrão para dataframe
#Configurando o padrão csv para que conseguir ler os dados, Pandas utiliza UTF-8, Precisamos configurar a usada pelo portal da transparência, que utiliza "Windows-1252 com separador ";"
df_viagens = pd.read_csv(caminho_dados, encoding="Windows-1252", sep=";")
pd.set_option('display.max_columns', None)

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18159396                 000001/23
# 2                                  18236583                 000018/23
# 3                                  18288418              000007/23-1C
# 4                                  18296348                 000070/23
# ...                                     ...                       ...
# 829689                           2023001618             Sem informaçã
# 829690                           2023001619             Sem informaçã
# 829691                           2023001628             Sem informaçã
# 829692                           2023001631             Sem informaçã
# 829693                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# ...

# %%
#Verificando coluna 'Nome do órgão superior'
df_viagens["Nome do órgão superior"]
# Out:
# 0         Ministério da Educação
# 1         Ministério da Educação
# 2         Ministério da Educação
# 3           Ministério da Defesa
# 4         Ministério da Educação
#                    ...
# 829689            Sem informação
# 829690            Sem informação
# 829691            Sem informação
# 829692            Sem informação
# 829693            Sem informação
# Name: Nome do órgão superior, Length: 829694, dtype: object

# %%
#Verificando valor da diária
df_viagens["Valor diárias"]
# Out:
# 0             0,00
# 1             0,00
# 2             0,00
# 3         39565,70
# 4          1013,96
#             ...
# 829689      606,89
# 829690     1089,00
# 829691      734,13
# 829692      319,28
# 829693        0,00
# Name: Valor diárias, Length: 829694, dtype: object

# %%
#Para selecionar mais de uma coluna é necessário informar como uma lista
colunas = ["Nome do órgão superior", "Valor diárias"]
df_viagens[colunas]
# Out:
#         Nome do órgão superior Valor diárias
# 0       Ministério da Educação          0,00
# 1       Ministério da Educação          0,00
# 2       Ministério da Educação          0,00
# 3         Ministério da Defesa      39565,70
# 4       Ministério da Educação       1013,96
# ...                        ...           ...
# 829689          Sem informação        606,89
# 829690          Sem informação       1089,00
# 829691          Sem informação        734,13
# 829692          Sem informação        319,28
# 829693          Sem informação          0,00
#
# [829694 rows x 2 columns]

# %%
#Passando as informações para letra maiúscula
df_viagens["Nome do órgão superior"].str.upper()
# Out:
# 0         MINISTÉRIO DA EDUCAÇÃO
# 1         MINISTÉRIO DA EDUCAÇÃO
# 2         MINISTÉRIO DA EDUCAÇÃO
# 3           MINISTÉRIO DA DEFESA
# 4         MINISTÉRIO DA EDUCAÇÃO
#                    ...
# 829689            SEM INFORMAÇÃO
# 829690            SEM INFORMAÇÃO
# 829691            SEM INFORMAÇÃO
# 829692            SEM INFORMAÇÃO
# 829693            SEM INFORMAÇÃO
# Name: Nome do órgão superior, Length: 829694, dtype: object

# %%
#str.len = length para medir a largura da string
df_viagens["Nome do órgão superior"].str.len()
# Out:
# 0         22
# 1         22
# 2         22
# 3         20
# 4         22
#           ..
# 829689    14
# 829690    14
# 829691    14
# 829692    14
# 829693    14
# Name: Nome do órgão superior, Length: 829694, dtype: int64

# %%
df_viagens["Nome do órgão superior"].str.upper().str.replace('MINISTÉRIO', 'MIN.') #str.replace = troca alguns caracteres, o primeiro argumento é como a string está e o segundo argumento como deve ficar com a mudança.
# Out:
# 0         MIN. DA EDUCAÇÃO
# 1         MIN. DA EDUCAÇÃO
# 2         MIN. DA EDUCAÇÃO
# 3           MIN. DA DEFESA
# 4         MIN. DA EDUCAÇÃO
#                 ...
# 829689      SEM INFORMAÇÃO
# 829690      SEM INFORMAÇÃO
# 829691      SEM INFORMAÇÃO
# 829692      SEM INFORMAÇÃO
# 829693      SEM INFORMAÇÃO
# Name: Nome do órgão superior, Length: 829694, dtype: object

# %%
df_viagens[['Valor diárias', 'Valor passagens']]
# Out:
#        Valor diárias Valor passagens
# 0               0,00            0,00
# 1               0,00         7894,50
# 2               0,00            0,00
# 3           39565,70         7434,13
# 4            1013,96            0,00
# ...              ...             ...
# 829689        606,89         3331,29
# 829690       1089,00         1837,18
# 829691        734,13         4555,95
# 829692        319,28         3745,53
# 829693          0,00         2961,55
#
# [829694 rows x 2 columns]

# %%
df_viagens["Valor diárias"]
# Out:
# 0             0,00
# 1             0,00
# 2             0,00
# 3         39565,70
# 4          1013,96
#             ...
# 829689      606,89
# 829690     1089,00
# 829691      734,13
# 829692      319,28
# 829693        0,00
# Name: Valor diárias, Length: 829694, dtype: object

# %%
#df_viagens["Valor passagens"] = df_viagens["Valor passagens"].str.replace(',', '.').astype(float) #Cast de object para float
#df_viagens["Valor devolução"] = df_viagens["Valor devolução"].str.replace(',', '.').astype(float)
#df_viagens["Valor outros gastos"] = df_viagens["Valor outros gastos"].str.replace(',', '.').astype(float)
#df_viagens["Valor diárias"] = df_viagens["Valor diárias"].str.replace(',', '.').astype(float)

# %%
df_viagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829694 entries, 0 to 829693
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Identificador do processo de viagem  829694 non-null  int64
#  1   Número da Proposta (PCDP)            829694 non-null  object
#  2   Situação                             829694 non-null  object
#  3   Viagem Urgente                       829694 non-null  object
#  4   Justificativa Urgência Viagem        829592 non-null  object
#  5   Código do órgão superior             829694 non-null  int64
#  6   Nome do órgão superior               829694 non-null  object
#  7   Código órgão solicitante             829694 non-null  int64
#  8   Nome órgão solicitante               829694 non-null  object
#  9   CPF viajante                         749562 non-null  object
#  10  Nome                                 829694 non-null  object
# ...

# %%
df_viagens["Valor diárias"] + df_viagens["Valor passagens"]
# Out:
# 0                0,000,00
# 1             0,007894,50
# 2                0,000,00
# 3         39565,707434,13
# 4             1013,960,00
#                ...
# 829689      606,893331,29
# 829690     1089,001837,18
# 829691      734,134555,95
# 829692      319,283745,53
# 829693        0,002961,55
# Length: 829694, dtype: object

# %%
df_viagens = pd.read_csv(caminho_dados, encoding="Windows-1252", sep=";" , decimal = ",") #decimal especifica virgula como separador decimal
pd.set_option('display.max_columns', None)

# %%
#Criando a coluna despesa
df_viagens['Despesas'] = df_viagens["Valor diárias"] + df_viagens["Valor passagens"] + df_viagens["Valor outros gastos"]

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18159396                 000001/23
# 2                                  18236583                 000018/23
# 3                                  18288418              000007/23-1C
# 4                                  18296348                 000070/23
# ...                                     ...                       ...
# 829689                           2023001618             Sem informaçã
# 829690                           2023001619             Sem informaçã
# 829691                           2023001628             Sem informaçã
# 829692                           2023001631             Sem informaçã
# 829693                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# ...

# %%
#normalize, normaliza os dados tornando-os proporcionais, a multiplicação por 100 é para melhorar a visualização em porcentagem
(df_viagens['Cargo'].value_counts(normalize=True) *100).rename('Proporção de viagens'). reset_index()
# Out:
#                                        Cargo  Proporção de viagens
# 0          Informações protegidas por sigilo             23.388186
# 1           PROFESSOR DO MAGISTERIO SUPERIOR             10.821019
# 2      PROFESSOR ENS BASICO TECN TECNOLOGICO              7.429079
# 3                CONTRATADO LEI 8745/93 - NI              3.513829
# 4        AUDITOR FISCAL FEDERAL AGROPECUARIO              3.276175
# ..                                       ...                   ...
# 818                              ANALISTA II              0.000198
# 819                               COSTUREIRO              0.000198
# 820  ANALISTA DE CONTROLE ECON FINANCEIRO SR              0.000198
# 821                       MEDICO I - 36HORAS              0.000198
# 822       CARGO ASSESS-1- EX-TER-AGREG-CCX-5              0.000198
#
# [823 rows x 2 columns]

# %%
#Formatando para duas casas decimais depois da virgula
pd.set_option('display.float_format', '{:.2f}'.format)
#df_viagens.groupby("Cargo")['Despesas'].sum().reset_index().sort_values(by = 'Despesas' , ascending=False)
#df_viagens.groupby("Cargo")['Despesas'].mean().reset_index().sort_values(by = 'Despesas' , ascending=False) #Tirar a média de gastos
#df_viagens.groupby("Cargo")['Despesas'].max().reset_index().sort_values(by = 'Despesas' , ascending=False) #viagem com maior despesa
#df_viagens.groupby("Cargo")['Despesas'].min().reset_index().sort_values(by = 'Despesas' , ascending=False) #viagem com menor despesa
#df_viagens.groupby("Cargo")['Despesas'].first().reset_index().sort_values(by = 'Despesas' , ascending=False) #Primeira viagem registrada
df_viagens.groupby("Cargo")['Despesas'].last().reset_index().sort_values(by = 'Despesas' , ascending=False) #Ultima viagem registrada
# Out:
#                                         Cargo  Despesas
# 742                    TECNICO EM NIVEL MEDIO  43039.20
# 326     DELEGADO DE POLICIA - PRIMEIRA CLASSE  34105.32
# 407    ESPECIALISTA EM METROLOGIA E QUALIDADE  29849.15
# 554                          PRIMEIRO TENENTE  16107.07
# 525    PAPILOSCOPISTA POLICIAL-SEGUNDA CLASSE  15421.69
# ..                                        ...       ...
# 749               TECNICO EM PROTESE DENTARIA      0.00
# 262       AUXILIAR DE VETERINARIA E ZOOTECNIA      0.00
# 20         AGENTE DE ATIVIDADES AGROPECUARIAS      0.00
# 24   AGENTE DE INSP SANIT IND PROD ORIGEM ANI      0.00
# 0               AAD-AUX DE RECURSOS MATERIAIS      0.00
#
# [823 rows x 2 columns]

# %% [markdown]
# ** Series boleanas e filtros **

# %%
viagens_por_cargo = (df_viagens['Cargo'].value_counts(normalize=True) * 100).rename('Proporção de viagens').reset_index()

# %%
filtro_mais_de_1_pct = viagens_por_cargo['Proporção de viagens'] >1

# %%
viagens_por_cargo
# Out:
#                                        Cargo  Proporção de viagens
# 0          Informações protegidas por sigilo                 23.39
# 1           PROFESSOR DO MAGISTERIO SUPERIOR                 10.82
# 2      PROFESSOR ENS BASICO TECN TECNOLOGICO                  7.43
# 3                CONTRATADO LEI 8745/93 - NI                  3.51
# 4        AUDITOR FISCAL FEDERAL AGROPECUARIO                  3.28
# ..                                       ...                   ...
# 818                              ANALISTA II                  0.00
# 819                               COSTUREIRO                  0.00
# 820  ANALISTA DE CONTROLE ECON FINANCEIRO SR                  0.00
# 821                       MEDICO I - 36HORAS                  0.00
# 822       CARGO ASSESS-1- EX-TER-AGREG-CCX-5                  0.00
#
# [823 rows x 2 columns]

# %%
viagens_por_cargo[filtro_mais_de_1_pct]
# Out:
#                                        Cargo  Proporção de viagens
# 0          Informações protegidas por sigilo                 23.39
# 1           PROFESSOR DO MAGISTERIO SUPERIOR                 10.82
# 2      PROFESSOR ENS BASICO TECN TECNOLOGICO                  7.43
# 3                CONTRATADO LEI 8745/93 - NI                  3.51
# 4        AUDITOR FISCAL FEDERAL AGROPECUARIO                  3.28
# 5                         ANALISTA AMBIENTAL                  2.69
# 6                ASSISTENTE EM ADMINISTRAçãO                  2.31
# 7    TECNICO INFOR GEOGRAFICAS E ESTATISTICA                  2.14
# 8                   TECNICO DO SEGURO SOCIAL                  2.11
# 9   AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL                  1.99
# 10    ANALISTA TRIBUTARIO REC FEDERAL BRASIL                  1.68
# 11                AUDITOR FISCAL DO TRABALHO                  1.54
# 12                                 MOTORISTA                  1.51
# ...

# %%
filtro_tecnico = viagens_por_cargo['Cargo'].str.startswith('TECNICO')

# %%
viagens_por_cargo[filtro_tecnico]
# Out:
#                                        Cargo  Proporção de viagens
# 7    TECNICO INFOR GEOGRAFICAS E ESTATISTICA                  2.14
# 8                   TECNICO DO SEGURO SOCIAL                  2.11
# 14                         TECNICO AMBIENTAL                  1.18
# 18                    TECNICO ADMINISTRATIVO                  0.87
# 23          TECNICO EM ASSUNTOS EDUCACIONAIS                  0.57
# ..                                       ...                   ...
# 791             TECNICO NM - 02 (DEC JUD-ME)                  0.00
# 801                    TECNICO DE MANUTENCAO                  0.00
# 803                         TECNICO EDUCACAO                  0.00
# 811                  TECNICO ESP SERV ECONOM                  0.00
# 817               TECNICO DE PROCESSAMENTO I                  0.00
#
# [142 rows x 2 columns]

# %%
viagens_por_cargo[filtro_tecnico & filtro_mais_de_1_pct]
# Out:
#                                       Cargo  Proporção de viagens
# 7   TECNICO INFOR GEOGRAFICAS E ESTATISTICA                  2.14
# 8                  TECNICO DO SEGURO SOCIAL                  2.11
# 14                        TECNICO AMBIENTAL                  1.18

# %%
gastos_totais_por_cargo = df_viagens.groupby('Cargo')['Despesas'].sum().reset_index()

# %%
gastos_totais_por_cargo[gastos_totais_por_cargo['Despesas'] >10_000_000]
# Out:
#                                         Cargo     Despesas
# 15                      AGENTE ADMINISTRATIVO  15018571.20
# 72                         ANALISTA AMBIENTAL  35363434.51
# 95                  ANALISTA DO SEGURO SOCIAL  15990188.61
# 113    ANALISTA TRIBUTARIO REC FEDERAL BRASIL  14875855.38
# 179               ASSISTENTE EM ADMINISTRAçãO  15145672.63
# 208                AUDITOR FISCAL DO TRABALHO  10376688.67
# 209       AUDITOR FISCAL FEDERAL AGROPECUARIO  24315111.98
# 210  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL  24406804.29
# 316               CONTRATADO LEI 8745/93 - NI  17510463.07
# 386     ESP EM REG DE SERV PUB DE TELECOMUNIC  10037621.59
# 387         ESP EM REGULACAO DE AVIACAO CIVIL  12716538.17
# 390   ESP EM REGULACAO E VIGILANCIA SANITARIA  24451002.94
# 444         Informações protegidas por sigilo 373884828.89
# 481               MINISTRO DE PRIMEIRA CLASSE  15869897.99
# 553                       PRIMEIRO SECRETARIO  13017368.36
# ...

# %%
gastos_medio_por_cargo = df_viagens.groupby('Cargo')['Despesas'].mean().reset_index()

# %%
gastos_medio_por_cargo[gastos_medio_por_cargo['Despesas'] >10_000]
# Out:
#                                        Cargo  Despesas
# 3       AAD-AUXILIAR DE RECURSOS FINANCEIROS  15545.94
# 37          AGENTE DE SERVICOS COMPLEMETARES  13975.38
# 170                ASSISTENTE DE CHANCELARIA  10360.63
# 231                AUXILIAR DE CONTABILIDADE  14015.48
# 258            AUXILIAR DE SERVICOS DIVERSOS  19000.96
# 269            AUXILIAR NM - 06 (DEC JUD-ME)  12323.94
# 306                              CONSELHEIRO  12232.35
# 326    DELEGADO DE POLICIA - PRIMEIRA CLASSE  34105.32
# 390  ESP EM REGULACAO E VIGILANCIA SANITARIA  13005.85
# 403        ESPECIALISTA EM ATIV HOSPITALARES  12686.31
# 472              MEDICO PROGRAMA MAIS MEDICO  11367.61
# 481              MINISTRO DE PRIMEIRA CLASSE  19051.50
# 482               MINISTRO DE SEGUNDA CLASSE  14504.94
# 499                   OFICIAL DE CHANCELARIA  11375.51
# 525   PAPILOSCOPISTA POLICIAL-SEGUNDA CLASSE  15421.69
# 552                        PRIMEIRO SARGENTO  17509.58
# ...

# %%
df_viagens['Cargo'].value_counts().sum() #verificando a quantidade de linhas contadas
# Out:
# np.int64(506200)

# %%
df_viagens['Cargo'].value_counts()
# Out:
# Cargo
# Informações protegidas por sigilo          118391
# PROFESSOR DO MAGISTERIO SUPERIOR            54776
# PROFESSOR ENS BASICO TECN TECNOLOGICO       37606
# CONTRATADO LEI 8745/93 - NI                 17787
# AUDITOR FISCAL FEDERAL AGROPECUARIO         16584
#                                             ...
# ANALISTA II                                     1
# COSTUREIRO                                      1
# ANALISTA DE CONTROLE ECON FINANCEIRO SR         1
# MEDICO I - 36HORAS                              1
# CARGO ASSESS-1- EX-TER-AGREG-CCX-5              1
# Name: count, Length: 823, dtype: int64

# %%
df_viagens['Cargo'].value_counts(dropna=False).reset_index() #Mostrando os valores nulos
# Out:
#                                        Cargo   count
# 0                                        NaN  323494
# 1          Informações protegidas por sigilo  118391
# 2           PROFESSOR DO MAGISTERIO SUPERIOR   54776
# 3      PROFESSOR ENS BASICO TECN TECNOLOGICO   37606
# 4                CONTRATADO LEI 8745/93 - NI   17787
# ..                                       ...     ...
# 819                              ANALISTA II       1
# 820                               COSTUREIRO       1
# 821  ANALISTA DE CONTROLE ECON FINANCEIRO SR       1
# 822                       MEDICO I - 36HORAS       1
# 823       CARGO ASSESS-1- EX-TER-AGREG-CCX-5       1
#
# [824 rows x 2 columns]

# %%
#excluindo linhas com valores nulos
df_viagens.dropna(subset = 'Cargo') #subset especifica onde eu quero realizar essa exclusão
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 2                                  18236583                 000018/23
# 4                                  18296348                 000070/23
# 6                                  18303291             Informações p
# 14                                 18350498             Informações p
# ...                                     ...                       ...
# 829689                           2023001618             Sem informaçã
# 829690                           2023001619             Sem informaçã
# 829691                           2023001628             Sem informaçã
# 829692                           2023001631             Sem informaçã
# 829693                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 2       Realizada            NÃO
# ...

# %%
#Caso não queira remover os valores nulos, mas marcar com alguma identificação
df_viagens['Cargo'] = df_viagens['Cargo'].fillna('NÃO IDENTIFICADO')
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18159396                 000001/23
# 2                                  18236583                 000018/23
# 3                                  18288418              000007/23-1C
# 4                                  18296348                 000070/23
# ...                                     ...                       ...
# 829689                           2023001618             Sem informaçã
# 829690                           2023001619             Sem informaçã
# 829691                           2023001628             Sem informaçã
# 829692                           2023001631             Sem informaçã
# 829693                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# ...

# %%
#Cast para data
df_viagens['Período - Data de início'] = pd.to_datetime(df_viagens['Período - Data de início'], format="%d/%m/%Y")
df_viagens['Período - Data de fim'] = pd.to_datetime(df_viagens['Período - Data de fim'], format="%d/%m/%Y")

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18159396                 000001/23
# 2                                  18236583                 000018/23
# 3                                  18288418              000007/23-1C
# 4                                  18296348                 000070/23
# ...                                     ...                       ...
# 829689                           2023001618             Sem informaçã
# 829690                           2023001619             Sem informaçã
# 829691                           2023001628             Sem informaçã
# 829692                           2023001631             Sem informaçã
# 829693                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# ...

# %%
df_viagens['Mês da viagem'] = df_viagens['Período - Data de início'].dt.month_name()

# %%
#df_viagens['Período - Data de fim'] - df_viagens['Período - Data de início']

#Para mostrar somente os dias de viagens e ocultar os outras informações do timedelta
df_viagens['Dias da viagem'] = (df_viagens['Período - Data de fim'] - df_viagens['Período - Data de início']).dt.days

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18159396                 000001/23
# 2                                  18236583                 000018/23
# 3                                  18288418              000007/23-1C
# 4                                  18296348                 000070/23
# ...                                     ...                       ...
# 829689                           2023001618             Sem informaçã
# 829690                           2023001619             Sem informaçã
# 829691                           2023001628             Sem informaçã
# 829692                           2023001631             Sem informaçã
# 829693                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# ...

# %%
#df_viagens.drop('Dias da viagem', axis=1, inplace=True)
#excluindo coluna

# %%
#Agregando informações(.agg)
(
    df_viagens
    .groupby('Cargo')
    .agg(
        despesa_media = ('Despesas' , 'mean'),
        duracao_media = ('Dias da viagem', 'mean'),
        despesas_totais = ('Despesas', 'sum'),
        destino_mais_frequente = ('Destinos', pd.Series.mode), #pd.Series.mode para calcular moda
        n_viagens = ('Nome', 'count')
        )
    .reset_index()
        )
# Out:
#                                     Cargo  despesa_media  duracao_media  \
# 0           AAD-AUX DE RECURSOS MATERIAIS        3592.10           9.40
# 1             AAD-AUXILIAR ADMINISTRATIVO         115.76           0.00
# 2               AAD-AUXILIAR DE OPERACOES        7973.39          16.71
# 3    AAD-AUXILIAR DE RECURSOS FINANCEIROS       15545.94           5.50
# 4         AAD-OPERADOR DE MICROCOMPUTADOR        1186.47           4.00
# ..                                    ...            ...            ...
# 819          VICE-PRESIDENTE DA REPUBLICA        7068.20           1.50
# 820                              VIDREIRO           0.00           6.00
# 821                             VIGILANTE         693.31           1.79
# 822                   VISITADOR SANITARIO        1402.57           3.88
# 823                           ZOOTECNISTA         655.56           1.87
#
#      despesas_totais             destino_mais_frequente  n_viagens
# ...

# %%
df_cargos = df_viagens['Cargo'].value_counts(normalize=True).reset_index()
df_cargos
# Out:
#                                        Cargo  proportion
# 0                           NÃO IDENTIFICADO        0.39
# 1          Informações protegidas por sigilo        0.14
# 2           PROFESSOR DO MAGISTERIO SUPERIOR        0.07
# 3      PROFESSOR ENS BASICO TECN TECNOLOGICO        0.05
# 4                CONTRATADO LEI 8745/93 - NI        0.02
# ..                                       ...         ...
# 819                              ANALISTA II        0.00
# 820                               COSTUREIRO        0.00
# 821  ANALISTA DE CONTROLE ECON FINANCEIRO SR        0.00
# 822                       MEDICO I - 36HORAS        0.00
# 823       CARGO ASSESS-1- EX-TER-AGREG-CCX-5        0.00
#
# [824 rows x 2 columns]

# %%
df_cargos.loc[df_cargos['proportion']>0.01]
# Out:
#                                        Cargo  proportion
# 0                           NÃO IDENTIFICADO        0.39
# 1          Informações protegidas por sigilo        0.14
# 2           PROFESSOR DO MAGISTERIO SUPERIOR        0.07
# 3      PROFESSOR ENS BASICO TECN TECNOLOGICO        0.05
# 4                CONTRATADO LEI 8745/93 - NI        0.02
# 5        AUDITOR FISCAL FEDERAL AGROPECUARIO        0.02
# 6                         ANALISTA AMBIENTAL        0.02
# 7                ASSISTENTE EM ADMINISTRAçãO        0.01
# 8    TECNICO INFOR GEOGRAFICAS E ESTATISTICA        0.01
# 9                   TECNICO DO SEGURO SOCIAL        0.01
# 10  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL        0.01
# 11    ANALISTA TRIBUTARIO REC FEDERAL BRASIL        0.01

# %%
df_cargos.loc[df_cargos['proportion']>0.01, 'Cargo']
# Out:
# 0                             NÃO IDENTIFICADO
# 1            Informações protegidas por sigilo
# 2             PROFESSOR DO MAGISTERIO SUPERIOR
# 3        PROFESSOR ENS BASICO TECN TECNOLOGICO
# 4                  CONTRATADO LEI 8745/93 - NI
# 5          AUDITOR FISCAL FEDERAL AGROPECUARIO
# 6                           ANALISTA AMBIENTAL
# 7                  ASSISTENTE EM ADMINISTRAçãO
# 8      TECNICO INFOR GEOGRAFICAS E ESTATISTICA
# 9                     TECNICO DO SEGURO SOCIAL
# 10    AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL
# 11      ANALISTA TRIBUTARIO REC FEDERAL BRASIL
# Name: Cargo, dtype: object

# %%
df_viagens_consolidado = (
    df_viagens
    .groupby('Cargo')
    .agg(
        despesa_media = ('Despesas' , 'mean'),
        duracao_media = ('Dias da viagem', 'mean'),
        despesas_totais = ('Despesas', 'sum'),
        destino_mais_frequente = ('Destinos', pd.Series.mode), #pd.Series.mode para calcular moda
        n_viagens = ('Nome', 'count')
        )
    .reset_index()
        )

# %%
cargos_relevantes = df_cargos.loc[df_cargos['proportion']>0.01, 'Cargo']

# %%
filtro = df_viagens_consolidado['Cargo'].isin(cargos_relevantes)

# %%
df_final = df_viagens_consolidado[filtro]

# %%
df_final
# Out:
#                                         Cargo  despesa_media  duracao_media  \
# 72                         ANALISTA AMBIENTAL        2595.67           5.13
# 113    ANALISTA TRIBUTARIO REC FEDERAL BRASIL        1747.22           3.06
# 179               ASSISTENTE EM ADMINISTRAçãO        1292.62           2.24
# 209       AUDITOR FISCAL FEDERAL AGROPECUARIO        1466.18           2.06
# 210  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL        2417.95           2.84
# 316               CONTRATADO LEI 8745/93 - NI         984.45           2.84
# 444         Informações protegidas por sigilo        3158.05           7.48
# 495                          NÃO IDENTIFICADO        3259.64           8.02
# 570          PROFESSOR DO MAGISTERIO SUPERIOR        2031.12           4.14
# 571     PROFESSOR ENS BASICO TECN TECNOLOGICO        1403.15           2.39
# 688                  TECNICO DO SEGURO SOCIAL        4305.63          11.38
# ...

# %%
df_final= df_final.sort_values(by = 'n_viagens', ascending=False)

# %%
df_final.plot(x = 'Cargo', y = 'n_viagens', kind = 'bar', color ='cadetblue')
# Out:
# <Axes: xlabel='Cargo'>

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(16,6))
ax.barh(df_final['Cargo'], df_final['n_viagens'], color='cadetblue')
ax.invert_yaxis()
ax.set_facecolor('#ebedeb')

fig.suptitle('Viagens por cargo público (2023)')

plt.figtext(0.75, 0.89, 'Fonte: Portal da Transparência', fontsize=8)

plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.yticks(fontsize=8)
plt.xlabel('Número de viagens')
plt.ylabel('Cargo')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,6))
ax.barh(df_final['Cargo'], df_final['despesa_media'], color='cadetblue')
ax.invert_yaxis()
ax.set_facecolor('#ebedeb')

fig.suptitle('Despesas média por cargo público (2023)')

plt.figtext(0.75, 0.89, 'Fonte: Portal da Transparência', fontsize=8)

plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.yticks(fontsize=8)
plt.xlabel('Despesas média')
plt.ylabel('Cargo')
plt.show()

# %%
df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  17821923              000001/23-1C
# 1                                  18159396                 000001/23
# 2                                  18236583                 000018/23
# 3                                  18288418              000007/23-1C
# 4                                  18296348                 000070/23
# ...                                     ...                       ...
# 829689                           2023001618             Sem informaçã
# 829690                           2023001619             Sem informaçã
# 829691                           2023001628             Sem informaçã
# 829692                           2023001631             Sem informaçã
# 829693                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente  \
# 0       Realizada            NÃO
# 1       Realizada            NÃO
# ...

# %%
fig, ax = plt.subplots(figsize=(16,6))
ax.scatter(df_viagens['Dias da viagem'], df_viagens['Despesas'], alpha=0.2, color = 'cadetblue')

# %%
fig, ax = plt.subplots(figsize=(16,6))
ax.scatter(df_viagens['Dias da viagem'], df_viagens['Despesas'], alpha=0.2, color= 'cadetblue')
#Dando um "Zoom em um canto específico do gráfico"
ax.set_xlim(0, 100)
ax.set_ylim(0, 25000)
# Out:
# (0.0, 25000.0)

# %%
(df_viagens['Despesas']>175_000).value_counts()
# Out:
# Despesas
# False    829689
# True          5
# Name: count, dtype: int64

# %%
filtro = df_viagens['Despesas']>175_000
df_viagens[filtro]
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 23525                              18654059             Informações p
# 129229                             18782567              000277/23-5C
# 129279                             18782625              000289/23-5C
# 207383                             18877982             Informações p
# 467597                             19194886                 004304/23
#
#          Situação Viagem Urgente  \
# 23525   Realizada            NÃO
# 129229  Realizada            SIM
# 129279  Realizada            SIM
# 207383  Realizada            NÃO
# 467597  Realizada            SIM
#
#                             Justificativa Urgência Viagem  \
# 23525   Informação protegida por sigilo nos termos da ...
# 129229  A autorização de afastamento foi publicada hoj...
# 129279  Devido ao cancelamento da Visita Oficial do PR...
# 207383  Informação protegida por sigilo nos termos da ...
# ...

# %%
caminho_dados_passagens = "/content/drive/MyDrive/Asimov/Análise de dados /2023_Passagem.csv"
df_passagens = pd.read_csv(caminho_dados_passagens, encoding="Windows-1252", sep=";")
pd.set_option('display.max_columns', None)
df_passagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  18159396                 000001/23
# 1                                  18159396                 000001/23
# 2                                  18288418              000007/23-1C
# 3                                  18302983                 000001/23
# 4                                  18306758                 000002/23
# ...                                     ...                       ...
# 389212                           2023001628             Sem informaçã
# 389213                           2023001628             Sem informaçã
# 389214                           2023001631             Sem informaçã
# 389215                           2023001631             Sem informaçã
# 389216                           2023001651             Sem informaçã
#
#        Meio de transporte País - Origem ida   UF - Origem ida  \
# 0                   Aéreo            Brasil    Rio de Janeiro
# ...

# %%
#Verificando os percursos de uma viagem na tabela passagens buscando pelo identificador
df_passagens[df_passagens['Identificador do processo de viagem'] == 19194886]
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 232773                             19194886                 004304/23
# 232774                             19194886                 004304/23
# 232775                             19194886                 004304/23
# 232776                             19194886                 004304/23
# 232777                             19194886                 004304/23
# 232778                             19194886                 004304/23
# 232779                             19194886                 004304/23
#
#        Meio de transporte          País - Origem ida UF - Origem ida  \
# 232773              Aéreo  Estados Unidos da América             NaN
# 232774              Aéreo                     Brasil       São Paulo
# 232775              Aéreo                  Indonésia             NaN
# 232776              Aéreo                  Filipinas             NaN
# ...

# %%
df_viagens.merge(df_passagens) #Junção de duas tabelas
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  18159396                 000001/23
# 1                                  18159396                 000001/23
# 2                                  18288418              000007/23-1C
# 3                                  18302983                 000001/23
# 4                                  18306758                 000002/23
# ...                                     ...                       ...
# 389220                           2023001628             Sem informaçã
# 389221                           2023001628             Sem informaçã
# 389222                           2023001631             Sem informaçã
# 389223                           2023001631             Sem informaçã
# 389224                           2023001651             Sem informaçã
#
#          Situação Viagem Urgente Justificativa Urgência Viagem  \
# ...

# %% [markdown]
# # Salvando o tabela

# %%
caminho_saida = "/content/drive/MyDrive/Asimov/Análise de dados /Output/tabela_final.xlsx"

# %%
df_final.to_excel(caminho_saida, index=False)

# %% [markdown]
# # Salvando gráfico

# %%
import matplotlib.pyplot as plt

caminho_figura = "/content/drive/MyDrive/Asimov/Análise de dados /Output/grafico.png"
fig, ax = plt.subplots(figsize=(16,6))
ax.barh(df_final['Cargo'], df_final['despesa_media'], color='cadetblue')
ax.invert_yaxis()
ax.set_facecolor('#ebedeb')

fig.suptitle('Despesas média por cargo público (2023)')

plt.figtext(0.75, 0.89, 'Fonte: Portal da Transparência', fontsize=8)

plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.yticks(fontsize=8)
plt.xlabel('Despesas média')
plt.ylabel('Cargo')
plt.savefig(caminho_figura, bbox_inches='tight')
